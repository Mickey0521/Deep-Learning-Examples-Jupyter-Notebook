# %%
import numpy as np
import csv

# %%
# which feature you want to extract
feature_set=[7,8,9,10]

# %%
# Predict the next hour before using n hours（ upper bound = 9 ）
prev_hrs=9

# %%
iteration=100000

# %%
raw = []
with open("train.csv",'r',encoding="big5") as train_f:
    train_f.readline() #ignore the 1st line
    for line in train_f:
        line = line.replace('NR', '0.0')
        data = line.strip('\n').split(',')
        data = data[3:]
        data = list(map(float, data))
        raw.append(data)

# %%
# Reshape as monthly data
train_data = []
for m in range(12):
    month_data = []

    for f in range(18):
        tmp = []

        for d in range(20):
            tmp += raw[360*m+18*d+f]

        month_data.append(tmp)

    train_data.append(month_data)

# %%
# Feature extraction
x = []
y_hat = [] #ground truth
for m in range(12):
    for hr in range(480-prev_hrs):
        y_hat.append(train_data[m][9][hr+prev_hrs])
        x.append([])
        for f in range(18):
            # Pick features that we want
            if f in feature_set:
                x[(480-prev_hrs)*m+hr] += train_data[m][f][hr:hr+prev_hrs]

# %%
x = np.array(x)
y_hat = np.array(y_hat)

print(x.shape)
print(y_hat.shape)
# Out:
# (5652, 36)
# (5652,)

# %%
# Regression with gradient descent
# dim(x)=len(x) by (prev_hrs*# features)
# dim(y_hat)=len(x)

# y = b + sum(w_Tx)
# Randomly determine model parameters
b = 1
w = np.random.randn(len(x[0]))
###################################
# you must set your learning rate #
###################################
lr = 1
ada_b = 0.0
ada_w = np.zeros(len(w))

prev_loss = float('inf')

# Gradient descent with adagrad
for k in range(iteration):
    b_grad = 0.0
    w_grad = np.zeros(len(w))

    # Set loss function as square error
    # Predicted value y from nth data = nth entry of X*w+b
    y = np.dot(x,w) + b
    dy = y_hat - y

    # Check current loss
    ###########################
    # you must implement here #
    ###########################
    loss = (np.sum(np.square(dy)))/len(y)
    print('%d iteration with loss %f\n' % (k, loss))

    # Stop when little improvement
    if(np.abs(prev_loss-loss) <= 1e-8):
        break

    # Compute gradients
    b_grad -= np.sum(2*dy)
    
    for i in range(len(w)):
        ###########################
        # you must implement here #
        ###########################
        w_grad[i] = w_grad[i]- np.dot(2*dy, x.T[i])

    # Compute AdaGrad terms
    ada_b += b_grad ** 2
    ada_w += w_grad ** 2

    # Update W, b
    b = b - lr/np.sqrt(ada_b) * b_grad
    for i in range(len(w)):
        ###########################
        # you must implement here #
        ###########################
        w[i] = w[i] - ( lr/np.sqrt(ada_w[i])) * w_grad[i]
        
    prev_loss = loss
# Out:
# 0 iteration with loss 125826.581899
#
# 1 iteration with loss 367327.260130
#
# 2 iteration with loss 52074.035167
#
# 3 iteration with loss 7458.099432
#
# 4 iteration with loss 3195.017284
#
# 5 iteration with loss 2672.592511
#
# 6 iteration with loss 2497.862789
#
# 7 iteration with loss 2368.686729
#
# 8 iteration with loss 2256.450381
#
# 9 iteration with loss 2156.867471
#
# 10 iteration with loss 2068.044634
#
# 11 iteration with loss 1988.513061
#
# 12 iteration with loss 1917.025850
#
# 13 iteration with loss 1852.513397
#
# 14 iteration with loss 1794.056898
#
# 15 iteration with loss 1740.866633
#
# 16 iteration with loss 1692.263494
#
# 17 iteration with loss 1647.663186
#
# 18 iteration with loss 1606.562712
#
# 19 iteration with loss 1568.528803
#
# 20 iteration with loss 1533.188010
#
# 21 iteration with loss 1500.218217
#
# 22 iteration with loss 1469.341377
#
# 23 iteration with loss 1440.317280
#
# 24 iteration with loss 1412.938220
#
# 25 iteration with loss 1387.024419
#
# 26 iteration with loss 1362.420100
#
# 27 iteration with loss 1338.990130
#
# 28 iteration with loss 1316.617130
#
# 29 iteration with loss 1295.199002
#
# 30 iteration with loss 1274.646803
#
# 31 iteration with loss 1254.882924
#
# 32 iteration with loss 1235.839523
#
# 33 iteration with loss 1217.457181
#
# 34 iteration with loss 1199.683748
#
# 35 iteration with loss 1182.473350
#
# 36 iteration with loss 1165.785541
#
# 37 iteration with loss 1149.584563
#
# 38 iteration with loss 1133.838720
#
# 39 iteration with loss 1118.519836
#
# 40 iteration with loss 1103.602788
#
# 41 iteration with loss 1089.065103
#
# 42 iteration with loss 1074.886615
#
# 43 iteration with loss 1061.049162
#
# 44 iteration with loss 1047.536334
#
# 45 iteration with loss 1034.333250
#
# 46 iteration with loss 1021.426366
#
# 47 iteration with loss 1008.803308
#
# 48 iteration with loss 996.452734
#
# 49 iteration with loss 984.364207
#
# 50 iteration with loss 972.528087
#
# 51 iteration with loss 960.935443
#
# 52 iteration with loss 949.577970
#
# 53 iteration with loss 938.447918
#
# 54 iteration with loss 927.538035
#
# 55 iteration with loss 916.841512
#
# 56 iteration with loss 906.351938
#
# 57 iteration with loss 896.063258
#
# 58 iteration with loss 885.969741
#
# 59 iteration with loss 876.065951
#
# 60 iteration with loss 866.346712
#
# 61 iteration with loss 856.807096
#
# 62 iteration with loss 847.442392
#
# 63 iteration with loss 838.248095
#
# 64 iteration with loss 829.219885
#
# 65 iteration with loss 820.353618
#
# 66 iteration with loss 811.645307
#
# 67 iteration with loss 803.091116
#
# 68 iteration with loss 794.687347
#
# 69 iteration with loss 786.430433
#
# 70 iteration with loss 778.316930
#
# 71 iteration with loss 770.343506
#
# 72 iteration with loss 762.506940
#
# 73 iteration with loss 754.804112
#
# 74 iteration with loss 747.231999
#
# 75 iteration with loss 739.787670
#
# 76 iteration with loss 732.468283
#
# 77 iteration with loss 725.271078
#
# 78 iteration with loss 718.193375
#
# 79 iteration with loss 711.232571
#
# 80 iteration with loss 704.386137
#
# 81 iteration with loss 697.651610
#
# 82 iteration with loss 691.026600
#
# 83 iteration with loss 684.508777
#
# 84 iteration with loss 678.095877
#
# 85 iteration with loss 671.785692
#
# 86 iteration with loss 665.576075
#
# 87 iteration with loss 659.464935
#
# 88 iteration with loss 653.450232
#
# 89 iteration with loss 647.529981
#
# 90 iteration with loss 641.702247
#
# 91 iteration with loss 635.965142
#
# 92 iteration with loss 630.316827
#
# 93 iteration with loss 624.755508
#
# 94 iteration with loss 619.279436
#
# 95 iteration with loss 613.886904
#
# 96 iteration with loss 608.576248
#
# 97 iteration with loss 603.345844
#
# 98 iteration with loss 598.194105
#
# 99 iteration with loss 593.119486
#
# 100 iteration with loss 588.120476
#
# 101 iteration with loss 583.195602
#
# 102 iteration with loss 578.343424
#
# 103 iteration with loss 573.562538
#
# 104 iteration with loss 568.851572
#
# 105 iteration with loss 564.209185
#
# 106 iteration with loss 559.634069
#
# 107 iteration with loss 555.124946
#
# 108 iteration with loss 550.680566
#
# 109 iteration with loss 546.299710
#
# 110 iteration with loss 541.981186
#
# 111 iteration with loss 537.723827
#
# 112 iteration with loss 533.526497
#
# 113 iteration with loss 529.388082
#
# 114 iteration with loss 525.307495
#
# 115 iteration with loss 521.283671
#
# 116 iteration with loss 517.315573
#
# 117 iteration with loss 513.402184
#
# 118 iteration with loss 509.542510
#
# 119 iteration with loss 505.735579
#
# 120 iteration with loss 501.980441
#
# 121 iteration with loss 498.276167
#
# 122 iteration with loss 494.621847
#
# 123 iteration with loss 491.016593
#
# 124 iteration with loss 487.459535
#
# 125 iteration with loss 483.949821
#
# 126 iteration with loss 480.486618
#
# 127 iteration with loss 477.069113
#
# 128 iteration with loss 473.696506
#
# 129 iteration with loss 470.368019
#
# 130 iteration with loss 467.082886
#
# 131 iteration with loss 463.840361
#
# 132 iteration with loss 460.639711
#
# 133 iteration with loss 457.480220
#
# 134 iteration with loss 454.361187
#
# 135 iteration with loss 451.281924
#
# 136 iteration with loss 448.241758
#
# 137 iteration with loss 445.240032
#
# 138 iteration with loss 442.276100
#
# 139 iteration with loss 439.349330
#
# 140 iteration with loss 436.459103
#
# 141 iteration with loss 433.604813
#
# 142 iteration with loss 430.785866
#
# 143 iteration with loss 428.001681
#
# 144 iteration with loss 425.251686
#
# 145 iteration with loss 422.535323
#
# 146 iteration with loss 419.852046
#
# 147 iteration with loss 417.201316
#
# 148 iteration with loss 414.582608
#
# 149 iteration with loss 411.995407
#
# 150 iteration with loss 409.439208
#
# 151 iteration with loss 406.913515
#
# 152 iteration with loss 404.417842
#
# 153 iteration with loss 401.951713
#
# 154 iteration with loss 399.514661
#
# 155 iteration with loss 397.106229
#
# 156 iteration with loss 394.725967
#
# 157 iteration with loss 392.373436
#
# 158 iteration with loss 390.048202
#
# 159 iteration with loss 387.749843
#
# 160 iteration with loss 385.477943
#
# 161 iteration with loss 383.232094
#
# 162 iteration with loss 381.011896
#
# 163 iteration with loss 378.816957
#
# 164 iteration with loss 376.646891
#
# 165 iteration with loss 374.501320
#
# 166 iteration with loss 372.379875
#
# 167 iteration with loss 370.282190
#
# 168 iteration with loss 368.207909
#
# 169 iteration with loss 366.156680
#
# 170 iteration with loss 364.128160
#
# 171 iteration with loss 362.122010
#
# 172 iteration with loss 360.137899
#
# 173 iteration with loss 358.175501
#
# 174 iteration with loss 356.234497
#
# 175 iteration with loss 354.314571
#
# 176 iteration with loss 352.415416
#
# 177 iteration with loss 350.536729
#
# 178 iteration with loss 348.678212
#
# 179 iteration with loss 346.839573
#
# 180 iteration with loss 345.020525
#
# 181 iteration with loss 343.220785
#
# 182 iteration with loss 341.440078
#
# 183 iteration with loss 339.678130
#
# 184 iteration with loss 337.934675
#
# 185 iteration with loss 336.209450
#
# 186 iteration with loss 334.502195
#
# 187 iteration with loss 332.812659
#
# 188 iteration with loss 331.140591
#
# 189 iteration with loss 329.485746
#
# 190 iteration with loss 327.847883
#
# 191 iteration with loss 326.226766
#
# 192 iteration with loss 324.622163
#
# 193 iteration with loss 323.033843
#
# 194 iteration with loss 321.461582
#
# 195 iteration with loss 319.905160
#
# 196 iteration with loss 318.364358
#
# 197 iteration with loss 316.838963
#
# 198 iteration with loss 315.328764
#
# 199 iteration with loss 313.833556
#
# 200 iteration with loss 312.353134
#
# 201 iteration with loss 310.887298
#
# 202 iteration with loss 309.435852
#
# 203 iteration with loss 307.998603
#
# 204 iteration with loss 306.575360
#
# 205 iteration with loss 305.165936
#
# 206 iteration with loss 303.770147
#
# 207 iteration with loss 302.387812
#
# 208 iteration with loss 301.018751
#
# 209 iteration with loss 299.662791
#
# 210 iteration with loss 298.319759
#
# 211 iteration with loss 296.989484
#
# 212 iteration with loss 295.671800
#
# 213 iteration with loss 294.366541
#
# 214 iteration with loss 293.073548
#
# 215 iteration with loss 291.792659
#
# 216 iteration with loss 290.523718
#
# 217 iteration with loss 289.266571
#
# 218 iteration with loss 288.021067
#
# 219 iteration with loss 286.787055
#
# 220 iteration with loss 285.564388
#
# 221 iteration with loss 284.352921
#
# 222 iteration with loss 283.152512
#
# 223 iteration with loss 281.963021
#
# 224 iteration with loss 280.784308
#
# 225 iteration with loss 279.616238
#
# 226 iteration with loss 278.458677
#
# 227 iteration with loss 277.311492
#
# 228 iteration with loss 276.174554
#
# 229 iteration with loss 275.047733
#
# 230 iteration with loss 273.930906
#
# 231 iteration with loss 272.823946
#
# 232 iteration with loss 271.726731
#
# 233 iteration with loss 270.639142
#
# 234 iteration with loss 269.561059
#
# 235 iteration with loss 268.492365
#
# 236 iteration with loss 267.432946
#
# 237 iteration with loss 266.382687
#
# 238 iteration with loss 265.341476
#
# 239 iteration with loss 264.309204
#
# 240 iteration with loss 263.285762
#
# 241 iteration with loss 262.271043
#
# 242 iteration with loss 261.264941
#
# 243 iteration with loss 260.267353
#
# 244 iteration with loss 259.278176
#
# 245 iteration with loss 258.297310
#
# 246 iteration with loss 257.324654
#
# 247 iteration with loss 256.360112
#
# 248 iteration with loss 255.403586
#
# 249 iteration with loss 254.454981
#
# 250 iteration with loss 253.514203
#
# 251 iteration with loss 252.581160
#
# 252 iteration with loss 251.655762
#
# 253 iteration with loss 250.737917
#
# 254 iteration with loss 249.827537
#
# 255 iteration with loss 248.924535
#
# 256 iteration with loss 248.028826
#
# 257 iteration with loss 247.140323
#
# 258 iteration with loss 246.258944
#
# 259 iteration with loss 245.384605
#
# 260 iteration with loss 244.517226
#
# 261 iteration with loss 243.656727
#
# 262 iteration with loss 242.803027
#
# 263 iteration with loss 241.956050
#
# 264 iteration with loss 241.115718
#
# 265 iteration with loss 240.281956
#
# 266 iteration with loss 239.454688
#
# 267 iteration with loss 238.633841
#
# 268 iteration with loss 237.819342
#
# 269 iteration with loss 237.011119
#
# 270 iteration with loss 236.209103
#
# 271 iteration with loss 235.413222
#
# 272 iteration with loss 234.623407
#
# 273 iteration with loss 233.839592
#
# 274 iteration with loss 233.061709
#
# 275 iteration with loss 232.289692
#
# 276 iteration with loss 231.523476
#
# 277 iteration with loss 230.762996
#
# 278 iteration with loss 230.008189
#
# 279 iteration with loss 229.258992
#
# 280 iteration with loss 228.515344
#
# 281 iteration with loss 227.777184
#
# 282 iteration with loss 227.044451
#
# 283 iteration with loss 226.317087
#
# 284 iteration with loss 225.595032
#
# 285 iteration with loss 224.878229
#
# 286 iteration with loss 224.166622
#
# 287 iteration with loss 223.460153
#
# 288 iteration with loss 222.758767
#
# 289 iteration with loss 222.062411
#
# 290 iteration with loss 221.371028
#
# 291 iteration with loss 220.684567
#
# 292 iteration with loss 220.002974
#
# 293 iteration with loss 219.326198
#
# 294 iteration with loss 218.654187
#
# 295 iteration with loss 217.986891
#
# 296 iteration with loss 217.324260
#
# 297 iteration with loss 216.666244
#
# 298 iteration with loss 216.012795
#
# 299 iteration with loss 215.363865
#
# 300 iteration with loss 214.719407
#
# 301 iteration with loss 214.079373
#
# 302 iteration with loss 213.443717
#
# 303 iteration with loss 212.812395
# 304 iteration with loss 212.185360
#
# 305 iteration with loss 211.562568
#
# 306 iteration with loss 210.943976
#
# 307 iteration with loss 210.329540
#
# 308 iteration with loss 209.719218
#
# 309 iteration with loss 209.112967
#
# 310 iteration with loss 208.510745
#
# 311 iteration with loss 207.912512
#
# 312 iteration with loss 207.318226
#
# 313 iteration with loss 206.727848
#
# 314 iteration with loss 206.141338
#
# 315 iteration with loss 205.558656
#
# 316 iteration with loss 204.979765
#
# 317 iteration with loss 204.404626
#
# 318 iteration with loss 203.833201
#
# 319 iteration with loss 203.265453
#
# 320 iteration with loss 202.701346
#
# 321 iteration with loss 202.140842
#
# 322 iteration with loss 201.583907
#
# 323 iteration with loss 201.030505
#
# 324 iteration with loss 200.480601
#
# 325 iteration with loss 199.934160
#
# 326 iteration with loss 199.391148
#
# 327 iteration with loss 198.851532
#
# 328 iteration with loss 198.315278
#
# 329 iteration with loss 197.782353
#
# 330 iteration with loss 197.252726
#
# 331 iteration with loss 196.726364
#
# 332 iteration with loss 196.203234
#
# 333 iteration with loss 195.683307
#
# 334 iteration with loss 195.166551
#
# 335 iteration with loss 194.652935
#
# 336 iteration with loss 194.142430
#
# 337 iteration with loss 193.635005
#
# 338 iteration with loss 193.130632
#
# 339 iteration with loss 192.629280
#
# 340 iteration with loss 192.130922
#
# 341 iteration with loss 191.635529
#
# 342 iteration with loss 191.143072
#
# 343 iteration with loss 190.653525
#
# 344 iteration with loss 190.166860
#
# 345 iteration with loss 189.683049
#
# 346 iteration with loss 189.202066
#
# 347 iteration with loss 188.723885
#
# 348 iteration with loss 188.248480
#
# 349 iteration with loss 187.775824
#
# 350 iteration with loss 187.305892
#
# 351 iteration with loss 186.838660
#
# 352 iteration with loss 186.374101
#
# 353 iteration with loss 185.912193
#
# 354 iteration with loss 185.452909
#
# 355 iteration with loss 184.996227
#
# 356 iteration with loss 184.542122
#
# 357 iteration with loss 184.090571
#
# 358 iteration with loss 183.641551
#
# 359 iteration with loss 183.195039
#
# 360 iteration with loss 182.751013
#
# 361 iteration with loss 182.309449
#
# 362 iteration with loss 181.870326
#
# 363 iteration with loss 181.433622
#
# 364 iteration with loss 180.999315
#
# 365 iteration with loss 180.567384
#
# 366 iteration with loss 180.137808
#
# 367 iteration with loss 179.710566
#
# 368 iteration with loss 179.285638
#
# 369 iteration with loss 178.863002
#
# 370 iteration with loss 178.442639
#
# 371 iteration with loss 178.024529
#
# 372 iteration with loss 177.608652
#
# 373 iteration with loss 177.194988
#
# 374 iteration with loss 176.783519
#
# 375 iteration with loss 176.374225
#
# 376 iteration with loss 175.967088
#
# 377 iteration with loss 175.562089
#
# 378 iteration with loss 175.159209
#
# 379 iteration with loss 174.758430
#
# 380 iteration with loss 174.359735
#
# 381 iteration with loss 173.963105
#
# 382 iteration with loss 173.568523
#
# 383 iteration with loss 173.175972
#
# 384 iteration with loss 172.785434
#
# 385 iteration with loss 172.396892
#
# 386 iteration with loss 172.010330
#
# 387 iteration with loss 171.625731
#
# 388 iteration with loss 171.243078
#
# 389 iteration with loss 170.862355
#
# 390 iteration with loss 170.483547
#
# 391 iteration with loss 170.106637
#
# 392 iteration with loss 169.731609
#
# 393 iteration with loss 169.358448
#
# 394 iteration with loss 168.987139
#
# 395 iteration with loss 168.617666
#
# 396 iteration with loss 168.250015
#
# 397 iteration with loss 167.884169
#
# 398 iteration with loss 167.520116
#
# 399 iteration with loss 167.157840
#
# 400 iteration with loss 166.797326
#
# 401 iteration with loss 166.438561
#
# 402 iteration with loss 166.081531
#
# 403 iteration with loss 165.726221
#
# 404 iteration with loss 165.372617
#
# 405 iteration with loss 165.020707
#
# 406 iteration with loss 164.670476
#
# 407 iteration with loss 164.321912
#
# 408 iteration with loss 163.975001
#
# 409 iteration with loss 163.629730
#
# 410 iteration with loss 163.286085
#
# 411 iteration with loss 162.944055
#
# 412 iteration with loss 162.603627
#
# 413 iteration with loss 162.264788
#
# 414 iteration with loss 161.927526
#
# 415 iteration with loss 161.591828
#
# 416 iteration with loss 161.257683
#
# 417 iteration with loss 160.925078
#
# 418 iteration with loss 160.594002
#
# 419 iteration with loss 160.264443
#
# 420 iteration with loss 159.936389
#
# 421 iteration with loss 159.609828
#
# 422 iteration with loss 159.284750
#
# 423 iteration with loss 158.961144
#
# 424 iteration with loss 158.638997
#
# 425 iteration with loss 158.318299
#
# 426 iteration with loss 157.999040
#
# 427 iteration with loss 157.681207
#
# 428 iteration with loss 157.364792
#
# 429 iteration with loss 157.049782
#
# 430 iteration with loss 156.736168
#
# 431 iteration with loss 156.423940
#
# 432 iteration with loss 156.113086
#
# 433 iteration with loss 155.803597
#
# 434 iteration with loss 155.495464
#
# 435 iteration with loss 155.188675
#
# 436 iteration with loss 154.883221
#
# 437 iteration with loss 154.579093
#
# 438 iteration with loss 154.276280
#
# 439 iteration with loss 153.974774
#
# 440 iteration with loss 153.674565
#
# 441 iteration with loss 153.375643
#
# 442 iteration with loss 153.077999
#
# 443 iteration with loss 152.781624
#
# 444 iteration with loss 152.486510
#
# 445 iteration with loss 152.192646
#
# 446 iteration with loss 151.900025
#
# 447 iteration with loss 151.608637
#
# 448 iteration with loss 151.318474
#
# 449 iteration with loss 151.029527
#
# 450 iteration with loss 150.741787
#
# 451 iteration with loss 150.455247
#
# 452 iteration with loss 150.169897
#
# 453 iteration with loss 149.885730
#
# 454 iteration with loss 149.602737
#
# 455 iteration with loss 149.320911
#
# 456 iteration with loss 149.040242
#
# 457 iteration with loss 148.760724
#
# 458 iteration with loss 148.482348
#
# 459 iteration with loss 148.205106
#
# 460 iteration with loss 147.928992
#
# 461 iteration with loss 147.653996
#
# 462 iteration with loss 147.380112
#
# 463 iteration with loss 147.107332
#
# 464 iteration with loss 146.835649
#
# 465 iteration with loss 146.565055
#
# 466 iteration with loss 146.295544
#
# 467 iteration with loss 146.027107
#
# 468 iteration with loss 145.759737
#
# 469 iteration with loss 145.493428
#
# 470 iteration with loss 145.228173
#
# 471 iteration with loss 144.963965
#
# 472 iteration with loss 144.700796
#
# 473 iteration with loss 144.438660
#
# 474 iteration with loss 144.177550
#
# 475 iteration with loss 143.917460
#
# 476 iteration with loss 143.658383
#
# 477 iteration with loss 143.400312
#
# 478 iteration with loss 143.143241
#
# 479 iteration with loss 142.887163
#
# 480 iteration with loss 142.632073
#
# 481 iteration with loss 142.377963
#
# 482 iteration with loss 142.124828
#
# 483 iteration with loss 141.872661
#
# 484 iteration with loss 141.621456
#
# 485 iteration with loss 141.371207
#
# 486 iteration with loss 141.121908
#
# 487 iteration with loss 140.873554
#
# 488 iteration with loss 140.626137
#
# 489 iteration with loss 140.379653
#
# 490 iteration with loss 140.134095
#
# 491 iteration with loss 139.889458
#
# 492 iteration with loss 139.645736
#
# 493 iteration with loss 139.402923
#
# 494 iteration with loss 139.161015
#
# 495 iteration with loss 138.920004
#
# 496 iteration with loss 138.679886
#
# 497 iteration with loss 138.440656
#
# 498 iteration with loss 138.202307
#
# 499 iteration with loss 137.964835
#
# 500 iteration with loss 137.728235
#
# 501 iteration with loss 137.492500
#
# 502 iteration with loss 137.257626
#
# 503 iteration with loss 137.023608
#
# 504 iteration with loss 136.790440
#
# 505 iteration with loss 136.558118
#
# 506 iteration with loss 136.326636
#
# 507 iteration with loss 136.095989
#
# 508 iteration with loss 135.866173
#
# 509 iteration with loss 135.637183
#
# 510 iteration with loss 135.409014
#
# 511 iteration with loss 135.181660
#
# 512 iteration with loss 134.955118
#
# 513 iteration with loss 134.729382
#
# 514 iteration with loss 134.504448
#
# 515 iteration with loss 134.280311
#
# 516 iteration with loss 134.056967
#
# 517 iteration with loss 133.834411
#
# 518 iteration with loss 133.612638
#
# 519 iteration with loss 133.391644
#
# 520 iteration with loss 133.171425
#
# 521 iteration with loss 132.951976
#
# 522 iteration with loss 132.733293
#
# 523 iteration with loss 132.515371
#
# 524 iteration with loss 132.298206
#
# 525 iteration with loss 132.081795
#
# 526 iteration with loss 131.866132
#
# 527 iteration with loss 131.651213
#
# 528 iteration with loss 131.437035
#
# 529 iteration with loss 131.223593
#
# 530 iteration with loss 131.010883
#
# 531 iteration with loss 130.798901
#
# 532 iteration with loss 130.587643
#
# 533 iteration with loss 130.377106
#
# 534 iteration with loss 130.167284
#
# 535 iteration with loss 129.958175
#
# 536 iteration with loss 129.749774
#
# 537 iteration with loss 129.542078
#
# 538 iteration with loss 129.335082
#
# 539 iteration with loss 129.128784
#
# 540 iteration with loss 128.923178
#
# 541 iteration with loss 128.718262
#
# 542 iteration with loss 128.514031
#
# 543 iteration with loss 128.310483
#
# 544 iteration with loss 128.107613
#
# 545 iteration with loss 127.905418
#
# 546 iteration with loss 127.703894
#
# 547 iteration with loss 127.503038
#
# 548 iteration with loss 127.302846
#
# 549 iteration with loss 127.103314
#
# 550 iteration with loss 126.904440
#
# 551 iteration with loss 126.706220
#
# 552 iteration with loss 126.508650
#
# 553 iteration with loss 126.311727
#
# 554 iteration with loss 126.115448
#
# 555 iteration with loss 125.919809
#
# 556 iteration with loss 125.724807
#
# 557 iteration with loss 125.530439
#
# 558 iteration with loss 125.336701
#
# 559 iteration with loss 125.143590
#
# 560 iteration with loss 124.951104
#
# 561 iteration with loss 124.759238
#
# 562 iteration with loss 124.567991
#
# 563 iteration with loss 124.377357
#
# 564 iteration with loss 124.187336
#
# 565 iteration with loss 123.997922
#
# 566 iteration with loss 123.809115
#
# 567 iteration with loss 123.620909
#
# 568 iteration with loss 123.433303
#
# 569 iteration with loss 123.246293
#
# 570 iteration with loss 123.059876
#
# 571 iteration with loss 122.874050
#
# 572 iteration with loss 122.688812
#
# 573 iteration with loss 122.504158
#
# 574 iteration with loss 122.320086
#
# 575 iteration with loss 122.136593
#
# 576 iteration with loss 121.953676
#
# 577 iteration with loss 121.771332
#
# 578 iteration with loss 121.589559
#
# 579 iteration with loss 121.408353
#
# 580 iteration with loss 121.227713
#
# 581 iteration with loss 121.047634
#
# 582 iteration with loss 120.868115
#
# 583 iteration with loss 120.689154
#
# 584 iteration with loss 120.510746
#
# 585 iteration with loss 120.332889
#
# 586 iteration with loss 120.155582
#
# 587 iteration with loss 119.978821
#
# 588 iteration with loss 119.802604
#
# 589 iteration with loss 119.626928
#
# 590 iteration with loss 119.451790
#
# 591 iteration with loss 119.277188
#
# 592 iteration with loss 119.103120
#
# 593 iteration with loss 118.929583
#
# 594 iteration with loss 118.756575
#
# 595 iteration with loss 118.584093
#
# 596 iteration with loss 118.412134
#
# 597 iteration with loss 118.240697
#
# 598 iteration with loss 118.069778
#
# 599 iteration with loss 117.899376
#
# 600 iteration with loss 117.729488
#
# 601 iteration with loss 117.560111
#
# 602 iteration with loss 117.391244
#
# 603 iteration with loss 117.222884
#
# 604 iteration with loss 117.055028
#
# 605 iteration with loss 116.887675
#
# 606 iteration with loss 116.720823
#
# 607 iteration with loss 116.554468
#
# 608 iteration with loss 116.388608
#
# 609 iteration with loss 116.223242
#
# 610 iteration with loss 116.058367
#
# 611 iteration with loss 115.893982
#
# 612 iteration with loss 115.730082
#
# 613 iteration with loss 115.566668
#
# 614 iteration with loss 115.403736
#
# 615 iteration with loss 115.241284
#
# 616 iteration with loss 115.079311
#
# 617 iteration with loss 114.917813
# 618 iteration with loss 114.756790
#
# 619 iteration with loss 114.596238
#
# 620 iteration with loss 114.436157
#
# 621 iteration with loss 114.276543
#
# 622 iteration with loss 114.117394
#
# 623 iteration with loss 113.958710
#
# 624 iteration with loss 113.800487
#
# 625 iteration with loss 113.642724
#
# 626 iteration with loss 113.485418
#
# 627 iteration with loss 113.328569
#
# 628 iteration with loss 113.172172
#
# 629 iteration with loss 113.016228
#
# 630 iteration with loss 112.860734
#
# 631 iteration with loss 112.705687
#
# 632 iteration with loss 112.551087
#
# 633 iteration with loss 112.396930
#
# 634 iteration with loss 112.243216
#
# 635 iteration with loss 112.089943
#
# 636 iteration with loss 111.937107
#
# 637 iteration with loss 111.784709
#
# 638 iteration with loss 111.632745
#
# 639 iteration with loss 111.481214
#
# 640 iteration with loss 111.330114
#
# 641 iteration with loss 111.179444
#
# 642 iteration with loss 111.029201
#
# 643 iteration with loss 110.879384
#
# 644 iteration with loss 110.729991
#
# 645 iteration with loss 110.581020
#
# 646 iteration with loss 110.432469
#
# 647 iteration with loss 110.284338
#
# 648 iteration with loss 110.136623
#
# 649 iteration with loss 109.989324
#
# 650 iteration with loss 109.842438
#
# 651 iteration with loss 109.695964
#
# 652 iteration with loss 109.549901
#
# 653 iteration with loss 109.404246
#
# 654 iteration with loss 109.258997
#
# 655 iteration with loss 109.114154
#
# 656 iteration with loss 108.969715
#
# 657 iteration with loss 108.825678
#
# 658 iteration with loss 108.682040
#
# 659 iteration with loss 108.538802
#
# 660 iteration with loss 108.395961
#
# 661 iteration with loss 108.253515
#
# 662 iteration with loss 108.111463
#
# 663 iteration with loss 107.969804
#
# 664 iteration with loss 107.828535
#
# 665 iteration with loss 107.687655
#
# 666 iteration with loss 107.547163
#
# 667 iteration with loss 107.407058
#
# 668 iteration with loss 107.267336
#
# 669 iteration with loss 107.127998
#
# 670 iteration with loss 106.989042
#
# 671 iteration with loss 106.850465
#
# 672 iteration with loss 106.712268
#
# 673 iteration with loss 106.574447
#
# 674 iteration with loss 106.437002
#
# 675 iteration with loss 106.299931
#
# 676 iteration with loss 106.163232
#
# 677 iteration with loss 106.026905
#
# 678 iteration with loss 105.890948
#
# 679 iteration with loss 105.755359
#
# 680 iteration with loss 105.620137
#
# 681 iteration with loss 105.485281
#
# 682 iteration with loss 105.350788
#
# 683 iteration with loss 105.216658
#
# 684 iteration with loss 105.082890
#
# 685 iteration with loss 104.949482
#
# 686 iteration with loss 104.816432
#
# 687 iteration with loss 104.683739
#
# 688 iteration with loss 104.551402
#
# 689 iteration with loss 104.419420
#
# 690 iteration with loss 104.287790
#
# 691 iteration with loss 104.156513
#
# 692 iteration with loss 104.025585
#
# 693 iteration with loss 103.895007
#
# 694 iteration with loss 103.764777
#
# 695 iteration with loss 103.634893
#
# 696 iteration with loss 103.505355
#
# 697 iteration with loss 103.376160
#
# 698 iteration with loss 103.247308
#
# 699 iteration with loss 103.118797
#
# 700 iteration with loss 102.990626
#
# 701 iteration with loss 102.862794
#
# 702 iteration with loss 102.735300
#
# 703 iteration with loss 102.608142
#
# 704 iteration with loss 102.481319
#
# 705 iteration with loss 102.354829
#
# 706 iteration with loss 102.228672
#
# 707 iteration with loss 102.102847
#
# 708 iteration with loss 101.977351
#
# 709 iteration with loss 101.852185
#
# 710 iteration with loss 101.727346
#
# 711 iteration with loss 101.602833
#
# 712 iteration with loss 101.478646
#
# 713 iteration with loss 101.354783
#
# 714 iteration with loss 101.231243
#
# 715 iteration with loss 101.108024
#
# 716 iteration with loss 100.985126
#
# 717 iteration with loss 100.862548
#
# 718 iteration with loss 100.740288
#
# 719 iteration with loss 100.618345
#
# 720 iteration with loss 100.496717
#
# 721 iteration with loss 100.375405
#
# 722 iteration with loss 100.254406
#
# 723 iteration with loss 100.133720
#
# 724 iteration with loss 100.013345
#
# 725 iteration with loss 99.893281
#
# 726 iteration with loss 99.773525
#
# 727 iteration with loss 99.654078
#
# 728 iteration with loss 99.534938
#
# 729 iteration with loss 99.416104
#
# 730 iteration with loss 99.297574
#
# 731 iteration with loss 99.179348
#
# 732 iteration with loss 99.061425
#
# 733 iteration with loss 98.943804
#
# 734 iteration with loss 98.826483
#
# 735 iteration with loss 98.709461
#
# 736 iteration with loss 98.592738
#
# 737 iteration with loss 98.476312
#
# 738 iteration with loss 98.360183
#
# 739 iteration with loss 98.244349
#
# 740 iteration with loss 98.128809
#
# 741 iteration with loss 98.013562
#
# 742 iteration with loss 97.898607
#
# 743 iteration with loss 97.783944
#
# 744 iteration with loss 97.669571
#
# 745 iteration with loss 97.555487
#
# 746 iteration with loss 97.441691
#
# 747 iteration with loss 97.328182
#
# 748 iteration with loss 97.214959
#
# 749 iteration with loss 97.102022
#
# 750 iteration with loss 96.989369
#
# 751 iteration with loss 96.876998
#
# 752 iteration with loss 96.764911
#
# 753 iteration with loss 96.653104
#
# 754 iteration with loss 96.541578
#
# 755 iteration with loss 96.430331
#
# 756 iteration with loss 96.319362
#
# 757 iteration with loss 96.208671
#
# 758 iteration with loss 96.098256
#
# 759 iteration with loss 95.988117
#
# 760 iteration with loss 95.878252
#
# 761 iteration with loss 95.768661
#
# 762 iteration with loss 95.659343
#
# 763 iteration with loss 95.550296
#
# 764 iteration with loss 95.441521
#
# 765 iteration with loss 95.333015
#
# 766 iteration with loss 95.224779
#
# 767 iteration with loss 95.116811
#
# 768 iteration with loss 95.009110
#
# 769 iteration with loss 94.901675
#
# 770 iteration with loss 94.794506
#
# 771 iteration with loss 94.687601
#
# 772 iteration with loss 94.580960
#
# 773 iteration with loss 94.474582
#
# 774 iteration with loss 94.368466
#
# 775 iteration with loss 94.262610
#
# 776 iteration with loss 94.157015
#
# 777 iteration with loss 94.051680
#
# 778 iteration with loss 93.946603
#
# 779 iteration with loss 93.841783
#
# 780 iteration with loss 93.737220
#
# 781 iteration with loss 93.632913
#
# 782 iteration with loss 93.528861
#
# 783 iteration with loss 93.425063
#
# 784 iteration with loss 93.321519
#
# 785 iteration with loss 93.218227
#
# 786 iteration with loss 93.115187
#
# 787 iteration with loss 93.012398
#
# 788 iteration with loss 92.909859
#
# 789 iteration with loss 92.807569
#
# 790 iteration with loss 92.705528
#
# 791 iteration with loss 92.603734
#
# 792 iteration with loss 92.502187
#
# 793 iteration with loss 92.400886
#
# 794 iteration with loss 92.299830
#
# 795 iteration with loss 92.199018
#
# 796 iteration with loss 92.098451
#
# 797 iteration with loss 91.998126
#
# 798 iteration with loss 91.898043
#
# 799 iteration with loss 91.798201
#
# 800 iteration with loss 91.698600
#
# 801 iteration with loss 91.599238
#
# 802 iteration with loss 91.500115
#
# 803 iteration with loss 91.401231
#
# 804 iteration with loss 91.302584
#
# 805 iteration with loss 91.204173
#
# 806 iteration with loss 91.105999
#
# 807 iteration with loss 91.008059
#
# 808 iteration with loss 90.910354
#
# 809 iteration with loss 90.812883
#
# 810 iteration with loss 90.715644
#
# 811 iteration with loss 90.618637
#
# 812 iteration with loss 90.521862
#
# 813 iteration with loss 90.425317
#
# 814 iteration with loss 90.329003
#
# 815 iteration with loss 90.232917
#
# 816 iteration with loss 90.137060
#
# 817 iteration with loss 90.041431
#
# 818 iteration with loss 89.946029
#
# 819 iteration with loss 89.850853
#
# 820 iteration with loss 89.755902
#
# 821 iteration with loss 89.661176
#
# 822 iteration with loss 89.566675
#
# 823 iteration with loss 89.472397
#
# 824 iteration with loss 89.378342
#
# 825 iteration with loss 89.284508
#
# 826 iteration with loss 89.190897
#
# 827 iteration with loss 89.097505
#
# 828 iteration with loss 89.004334
#
# 829 iteration with loss 88.911382
#
# 830 iteration with loss 88.818648
#
# 831 iteration with loss 88.726133
#
# 832 iteration with loss 88.633835
#
# 833 iteration with loss 88.541753
#
# 834 iteration with loss 88.449887
#
# 835 iteration with loss 88.358236
#
# 836 iteration with loss 88.266800
#
# 837 iteration with loss 88.175578
#
# 838 iteration with loss 88.084569
#
# 839 iteration with loss 87.993772
#
# 840 iteration with loss 87.903187
#
# 841 iteration with loss 87.812814
#
# 842 iteration with loss 87.722651
#
# 843 iteration with loss 87.632698
#
# 844 iteration with loss 87.542955
#
# 845 iteration with loss 87.453420
#
# 846 iteration with loss 87.364093
#
# 847 iteration with loss 87.274973
#
# 848 iteration with loss 87.186060
#
# 849 iteration with loss 87.097353
#
# 850 iteration with loss 87.008852
#
# 851 iteration with loss 86.920555
#
# 852 iteration with loss 86.832463
#
# 853 iteration with loss 86.744574
#
# 854 iteration with loss 86.656888
#
# 855 iteration with loss 86.569405
#
# 856 iteration with loss 86.482123
#
# 857 iteration with loss 86.395043
#
# 858 iteration with loss 86.308163
#
# 859 iteration with loss 86.221482
#
# 860 iteration with loss 86.135001
#
# 861 iteration with loss 86.048719
#
# 862 iteration with loss 85.962635
#
# 863 iteration with loss 85.876748
#
# 864 iteration with loss 85.791059
#
# 865 iteration with loss 85.705565
#
# 866 iteration with loss 85.620267
#
# 867 iteration with loss 85.535165
#
# 868 iteration with loss 85.450257
#
# 869 iteration with loss 85.365543
#
# 870 iteration with loss 85.281022
#
# 871 iteration with loss 85.196694
#
# 872 iteration with loss 85.112558
#
# 873 iteration with loss 85.028614
#
# 874 iteration with loss 84.944861
#
# 875 iteration with loss 84.861298
#
# 876 iteration with loss 84.777925
#
# 877 iteration with loss 84.694742
#
# 878 iteration with loss 84.611747
#
# 879 iteration with loss 84.528941
#
# 880 iteration with loss 84.446322
#
# 881 iteration with loss 84.363890
#
# 882 iteration with loss 84.281645
#
# 883 iteration with loss 84.199586
#
# 884 iteration with loss 84.117713
#
# 885 iteration with loss 84.036024
#
# 886 iteration with loss 83.954519
#
# 887 iteration with loss 83.873199
#
# 888 iteration with loss 83.792061
#
# 889 iteration with loss 83.711107
#
# 890 iteration with loss 83.630334
#
# 891 iteration with loss 83.549743
#
# 892 iteration with loss 83.469334
#
# 893 iteration with loss 83.389105
#
# 894 iteration with loss 83.309056
#
# 895 iteration with loss 83.229186
#
# 896 iteration with loss 83.149495
#
# 897 iteration with loss 83.069983
#
# 898 iteration with loss 82.990649
#
# 899 iteration with loss 82.911492
#
# 900 iteration with loss 82.832513
#
# 901 iteration with loss 82.753709
#
# 902 iteration with loss 82.675081
#
# 903 iteration with loss 82.596629
#
# 904 iteration with loss 82.518352
#
# 905 iteration with loss 82.440249
#
# 906 iteration with loss 82.362320
#
# 907 iteration with loss 82.284564
#
# 908 iteration with loss 82.206981
#
# 909 iteration with loss 82.129570
#
# 910 iteration with loss 82.052331
#
# 911 iteration with loss 81.975263
#
# 912 iteration with loss 81.898367
#
# 913 iteration with loss 81.821640
#
# 914 iteration with loss 81.745084
#
# 915 iteration with loss 81.668696
#
# 916 iteration with loss 81.592478
#
# 917 iteration with loss 81.516428
#
# 918 iteration with loss 81.440546
#
# 919 iteration with loss 81.364831
#
# 920 iteration with loss 81.289283
#
# 921 iteration with loss 81.213902
#
# 922 iteration with loss 81.138687
#
# 923 iteration with loss 81.063637
#
# 924 iteration with loss 80.988752
#
# 925 iteration with loss 80.914032
#
# 926 iteration with loss 80.839476
#
# 927 iteration with loss 80.765083
#
# 928 iteration with loss 80.690854
#
# 929 iteration with loss 80.616787
#
# 930 iteration with loss 80.542882
#
# 931 iteration with loss 80.469139
#
# 932 iteration with loss 80.395558
#
# 933 iteration with loss 80.322137
#
# 934 iteration with loss 80.248877
#
# 935 iteration with loss 80.175776
#
# 936 iteration with loss 80.102835
#
# 937 iteration with loss 80.030053
#
# 938 iteration with loss 79.957430
#
# 939 iteration with loss 79.884965
#
# 940 iteration with loss 79.812657
#
# 941 iteration with loss 79.740507
#
# 942 iteration with loss 79.668513
#
# 943 iteration with loss 79.596676
#
# 944 iteration with loss 79.524995
#
# 945 iteration with loss 79.453469
#
# 946 iteration with loss 79.382098
# 947 iteration with loss 79.310881
#
# 948 iteration with loss 79.239819
#
# 949 iteration with loss 79.168911
#
# 950 iteration with loss 79.098155
#
# 951 iteration with loss 79.027553
#
# 952 iteration with loss 78.957103
#
# 953 iteration with loss 78.886805
#
# 954 iteration with loss 78.816659
#
# 955 iteration with loss 78.746663
#
# 956 iteration with loss 78.676819
#
# 957 iteration with loss 78.607125
#
# 958 iteration with loss 78.537580
#
# 959 iteration with loss 78.468185
#
# 960 iteration with loss 78.398939
#
# 961 iteration with loss 78.329842
#
# 962 iteration with loss 78.260893
#
# 963 iteration with loss 78.192092
#
# 964 iteration with loss 78.123438
#
# 965 iteration with loss 78.054931
#
# 966 iteration with loss 77.986571
#
# 967 iteration with loss 77.918357
#
# 968 iteration with loss 77.850288
#
# 969 iteration with loss 77.782365
#
# 970 iteration with loss 77.714587
#
# 971 iteration with loss 77.646954
#
# 972 iteration with loss 77.579465
#
# 973 iteration with loss 77.512119
#
# 974 iteration with loss 77.444917
#
# 975 iteration with loss 77.377858
#
# 976 iteration with loss 77.310941
#
# 977 iteration with loss 77.244167
#
# 978 iteration with loss 77.177534
#
# 979 iteration with loss 77.111043
#
# 980 iteration with loss 77.044692
#
# 981 iteration with loss 76.978483
#
# 982 iteration with loss 76.912413
#
# 983 iteration with loss 76.846484
#
# 984 iteration with loss 76.780693
#
# 985 iteration with loss 76.715042
#
# 986 iteration with loss 76.649530
#
# 987 iteration with loss 76.584156
#
# 988 iteration with loss 76.518920
#
# 989 iteration with loss 76.453822
#
# 990 iteration with loss 76.388860
#
# 991 iteration with loss 76.324036
#
# 992 iteration with loss 76.259348
#
# 993 iteration with loss 76.194796
#
# 994 iteration with loss 76.130380
#
# 995 iteration with loss 76.066099
#
# 996 iteration with loss 76.001953
#
# 997 iteration with loss 75.937942
#
# 998 iteration with loss 75.874065
#
# 999 iteration with loss 75.810322
#
# 1000 iteration with loss 75.746712
#
# 1001 iteration with loss 75.683236
#
# 1002 iteration with loss 75.619892
#
# 1003 iteration with loss 75.556681
#
# 1004 iteration with loss 75.493601
#
# 1005 iteration with loss 75.430654
#
# 1006 iteration with loss 75.367838
#
# 1007 iteration with loss 75.305153
#
# 1008 iteration with loss 75.242598
#
# 1009 iteration with loss 75.180174
#
# 1010 iteration with loss 75.117880
#
# 1011 iteration with loss 75.055715
#
# 1012 iteration with loss 74.993680
#
# 1013 iteration with loss 74.931774
#
# 1014 iteration with loss 74.869996
#
# 1015 iteration with loss 74.808346
#
# 1016 iteration with loss 74.746824
#
# 1017 iteration with loss 74.685430
#
# 1018 iteration with loss 74.624163
#
# 1019 iteration with loss 74.563023
#
# 1020 iteration with loss 74.502009
#
# 1021 iteration with loss 74.441122
#
# 1022 iteration with loss 74.380360
#
# 1023 iteration with loss 74.319724
#
# 1024 iteration with loss 74.259213
#
# 1025 iteration with loss 74.198827
#
# 1026 iteration with loss 74.138565
#
# 1027 iteration with loss 74.078428
#
# 1028 iteration with loss 74.018414
#
# 1029 iteration with loss 73.958524
#
# 1030 iteration with loss 73.898757
#
# 1031 iteration with loss 73.839113
#
# 1032 iteration with loss 73.779591
#
# 1033 iteration with loss 73.720192
#
# 1034 iteration with loss 73.660914
#
# 1035 iteration with loss 73.601758
#
# 1036 iteration with loss 73.542723
#
# 1037 iteration with loss 73.483809
#
# 1038 iteration with loss 73.425016
#
# 1039 iteration with loss 73.366343
#
# 1040 iteration with loss 73.307790
#
# 1041 iteration with loss 73.249357
#
# 1042 iteration with loss 73.191043
#
# 1043 iteration with loss 73.132848
#
# 1044 iteration with loss 73.074771
#
# 1045 iteration with loss 73.016813
#
# 1046 iteration with loss 72.958974
#
# 1047 iteration with loss 72.901251
#
# 1048 iteration with loss 72.843647
#
# 1049 iteration with loss 72.786159
#
# 1050 iteration with loss 72.728789
#
# 1051 iteration with loss 72.671534
#
# 1052 iteration with loss 72.614397
#
# 1053 iteration with loss 72.557375
#
# 1054 iteration with loss 72.500468
#
# 1055 iteration with loss 72.443677
#
# 1056 iteration with loss 72.387001
#
# 1057 iteration with loss 72.330440
#
# 1058 iteration with loss 72.273993
#
# 1059 iteration with loss 72.217660
#
# 1060 iteration with loss 72.161441
#
# 1061 iteration with loss 72.105336
#
# 1062 iteration with loss 72.049344
#
# 1063 iteration with loss 71.993464
#
# 1064 iteration with loss 71.937698
#
# 1065 iteration with loss 71.882043
#
# 1066 iteration with loss 71.826501
#
# 1067 iteration with loss 71.771071
#
# 1068 iteration with loss 71.715752
#
# 1069 iteration with loss 71.660544
#
# 1070 iteration with loss 71.605447
#
# 1071 iteration with loss 71.550461
#
# 1072 iteration with loss 71.495585
#
# 1073 iteration with loss 71.440819
#
# 1074 iteration with loss 71.386163
#
# 1075 iteration with loss 71.331616
#
# 1076 iteration with loss 71.277178
#
# 1077 iteration with loss 71.222850
#
# 1078 iteration with loss 71.168630
#
# 1079 iteration with loss 71.114518
#
# 1080 iteration with loss 71.060514
#
# 1081 iteration with loss 71.006619
#
# 1082 iteration with loss 70.952830
#
# 1083 iteration with loss 70.899149
#
# 1084 iteration with loss 70.845575
#
# 1085 iteration with loss 70.792108
#
# 1086 iteration with loss 70.738747
#
# 1087 iteration with loss 70.685492
#
# 1088 iteration with loss 70.632343
#
# 1089 iteration with loss 70.579300
#
# 1090 iteration with loss 70.526362
#
# 1091 iteration with loss 70.473529
#
# 1092 iteration with loss 70.420801
#
# 1093 iteration with loss 70.368177
#
# 1094 iteration with loss 70.315657
#
# 1095 iteration with loss 70.263242
#
# 1096 iteration with loss 70.210930
#
# 1097 iteration with loss 70.158722
#
# 1098 iteration with loss 70.106617
#
# 1099 iteration with loss 70.054615
#
# 1100 iteration with loss 70.002715
#
# 1101 iteration with loss 69.950918
#
# 1102 iteration with loss 69.899223
#
# 1103 iteration with loss 69.847630
#
# 1104 iteration with loss 69.796139
#
# 1105 iteration with loss 69.744749
#
# 1106 iteration with loss 69.693460
#
# 1107 iteration with loss 69.642272
#
# 1108 iteration with loss 69.591185
#
# 1109 iteration with loss 69.540197
#
# 1110 iteration with loss 69.489310
#
# 1111 iteration with loss 69.438523
#
# 1112 iteration with loss 69.387836
#
# 1113 iteration with loss 69.337247
#
# 1114 iteration with loss 69.286758
#
# 1115 iteration with loss 69.236368
#
# 1116 iteration with loss 69.186076
#
# 1117 iteration with loss 69.135883
#
# 1118 iteration with loss 69.085788
#
# 1119 iteration with loss 69.035790
#
# 1120 iteration with loss 68.985890
#
# 1121 iteration with loss 68.936088
#
# 1122 iteration with loss 68.886382
#
# 1123 iteration with loss 68.836774
#
# 1124 iteration with loss 68.787262
#
# 1125 iteration with loss 68.737847
#
# 1126 iteration with loss 68.688527
#
# 1127 iteration with loss 68.639304
#
# 1128 iteration with loss 68.590176
#
# 1129 iteration with loss 68.541143
#
# 1130 iteration with loss 68.492206
#
# 1131 iteration with loss 68.443364
#
# 1132 iteration with loss 68.394616
#
# 1133 iteration with loss 68.345963
#
# 1134 iteration with loss 68.297404
#
# 1135 iteration with loss 68.248940
#
# 1136 iteration with loss 68.200568
#
# 1137 iteration with loss 68.152291
#
# 1138 iteration with loss 68.104107
#
# 1139 iteration with loss 68.056015
#
# 1140 iteration with loss 68.008017
#
# 1141 iteration with loss 67.960111
#
# 1142 iteration with loss 67.912298
#
# 1143 iteration with loss 67.864576
#
# 1144 iteration with loss 67.816947
#
# 1145 iteration with loss 67.769409
#
# 1146 iteration with loss 67.721963
#
# 1147 iteration with loss 67.674608
#
# 1148 iteration with loss 67.627344
#
# 1149 iteration with loss 67.580171
#
# 1150 iteration with loss 67.533088
#
# 1151 iteration with loss 67.486096
#
# 1152 iteration with loss 67.439194
#
# 1153 iteration with loss 67.392382
#
# 1154 iteration with loss 67.345659
#
# 1155 iteration with loss 67.299026
#
# 1156 iteration with loss 67.252482
#
# 1157 iteration with loss 67.206027
#
# 1158 iteration with loss 67.159661
#
# 1159 iteration with loss 67.113383
#
# 1160 iteration with loss 67.067194
#
# 1161 iteration with loss 67.021093
#
# 1162 iteration with loss 66.975080
#
# 1163 iteration with loss 66.929154
#
# 1164 iteration with loss 66.883316
#
# 1165 iteration with loss 66.837565
#
# 1166 iteration with loss 66.791902
#
# 1167 iteration with loss 66.746325
#
# 1168 iteration with loss 66.700835
#
# 1169 iteration with loss 66.655431
#
# 1170 iteration with loss 66.610113
#
# 1171 iteration with loss 66.564882
#
# 1172 iteration with loss 66.519736
#
# 1173 iteration with loss 66.474676
#
# 1174 iteration with loss 66.429701
#
# 1175 iteration with loss 66.384811
#
# 1176 iteration with loss 66.340006
#
# 1177 iteration with loss 66.295286
#
# 1178 iteration with loss 66.250651
#
# 1179 iteration with loss 66.206100
#
# 1180 iteration with loss 66.161633
#
# 1181 iteration with loss 66.117250
#
# 1182 iteration with loss 66.072950
#
# 1183 iteration with loss 66.028734
#
# 1184 iteration with loss 65.984602
#
# 1185 iteration with loss 65.940553
#
# 1186 iteration with loss 65.896586
#
# 1187 iteration with loss 65.852702
#
# 1188 iteration with loss 65.808901
#
# 1189 iteration with loss 65.765182
#
# 1190 iteration with loss 65.721545
#
# 1191 iteration with loss 65.677990
#
# 1192 iteration with loss 65.634517
#
# 1193 iteration with loss 65.591125
#
# 1194 iteration with loss 65.547815
#
# 1195 iteration with loss 65.504586
#
# 1196 iteration with loss 65.461437
#
# 1197 iteration with loss 65.418370
#
# 1198 iteration with loss 65.375383
#
# 1199 iteration with loss 65.332476
#
# 1200 iteration with loss 65.289650
#
# 1201 iteration with loss 65.246903
#
# 1202 iteration with loss 65.204236
#
# 1203 iteration with loss 65.161649
#
# 1204 iteration with loss 65.119141
#
# 1205 iteration with loss 65.076712
#
# 1206 iteration with loss 65.034363
#
# 1207 iteration with loss 64.992092
#
# 1208 iteration with loss 64.949900
#
# 1209 iteration with loss 64.907786
#
# 1210 iteration with loss 64.865750
#
# 1211 iteration with loss 64.823793
#
# 1212 iteration with loss 64.781913
#
# 1213 iteration with loss 64.740111
#
# 1214 iteration with loss 64.698387
#
# 1215 iteration with loss 64.656740
#
# 1216 iteration with loss 64.615170
#
# 1217 iteration with loss 64.573677
#
# 1218 iteration with loss 64.532261
#
# 1219 iteration with loss 64.490921
#
# 1220 iteration with loss 64.449658
#
# 1221 iteration with loss 64.408471
#
# 1222 iteration with loss 64.367360
#
# 1223 iteration with loss 64.326325
#
# 1224 iteration with loss 64.285366
#
# 1225 iteration with loss 64.244482
#
# 1226 iteration with loss 64.203673
#
# 1227 iteration with loss 64.162940
#
# 1228 iteration with loss 64.122281
#
# 1229 iteration with loss 64.081698
#
# 1230 iteration with loss 64.041189
#
# 1231 iteration with loss 64.000754
#
# 1232 iteration with loss 63.960394
#
# 1233 iteration with loss 63.920107
#
# 1234 iteration with loss 63.879895
#
# 1235 iteration with loss 63.839756
#
# 1236 iteration with loss 63.799691
#
# 1237 iteration with loss 63.759699
#
# 1238 iteration with loss 63.719781
#
# 1239 iteration with loss 63.679935
#
# 1240 iteration with loss 63.640163
#
# 1241 iteration with loss 63.600463
#
# 1242 iteration with loss 63.560836
#
# 1243 iteration with loss 63.521281
#
# 1244 iteration with loss 63.481798
#
# 1245 iteration with loss 63.442387
#
# 1246 iteration with loss 63.403048
#
# 1247 iteration with loss 63.363781
#
# 1248 iteration with loss 63.324585
#
# 1249 iteration with loss 63.285461
#
# 1250 iteration with loss 63.246407
#
# 1251 iteration with loss 63.207425
#
# 1252 iteration with loss 63.168514
#
# 1253 iteration with loss 63.129673
#
# 1254 iteration with loss 63.090903
#
# 1255 iteration with loss 63.052203
#
# 1256 iteration with loss 63.013573
#
# 1257 iteration with loss 62.975014
#
# 1258 iteration with loss 62.936524
#
# 1259 iteration with loss 62.898104
#
# 1260 iteration with loss 62.859753
#
# 1261 iteration with loss 62.821472
#
# 1262 iteration with loss 62.783260
#
# 1263 iteration with loss 62.745117
#
# 1264 iteration with loss 62.707043
#
# 1265 iteration with loss 62.669038
#
# 1266 iteration with loss 62.631101
#
# 1267 iteration with loss 62.593233
#
# 1268 iteration with loss 62.555433
#
# 1269 iteration with loss 62.517701
#
# 1270 iteration with loss 62.480036
#
# 1271 iteration with loss 62.442440
# 1272 iteration with loss 62.404911
#
# 1273 iteration with loss 62.367450
#
# 1274 iteration with loss 62.330056
#
# 1275 iteration with loss 62.292730
#
# 1276 iteration with loss 62.255470
#
# 1277 iteration with loss 62.218277
#
# 1278 iteration with loss 62.181151
#
# 1279 iteration with loss 62.144091
#
# 1280 iteration with loss 62.107098
#
# 1281 iteration with loss 62.070170
#
# 1282 iteration with loss 62.033309
#
# 1283 iteration with loss 61.996514
#
# 1284 iteration with loss 61.959785
#
# 1285 iteration with loss 61.923121
#
# 1286 iteration with loss 61.886523
#
# 1287 iteration with loss 61.849990
#
# 1288 iteration with loss 61.813522
#
# 1289 iteration with loss 61.777119
#
# 1290 iteration with loss 61.740782
#
# 1291 iteration with loss 61.704508
#
# 1292 iteration with loss 61.668300
#
# 1293 iteration with loss 61.632156
#
# 1294 iteration with loss 61.596076
#
# 1295 iteration with loss 61.560060
#
# 1296 iteration with loss 61.524108
#
# 1297 iteration with loss 61.488220
#
# 1298 iteration with loss 61.452396
#
# 1299 iteration with loss 61.416635
#
# 1300 iteration with loss 61.380938
#
# 1301 iteration with loss 61.345304
#
# 1302 iteration with loss 61.309733
#
# 1303 iteration with loss 61.274225
#
# 1304 iteration with loss 61.238780
#
# 1305 iteration with loss 61.203397
#
# 1306 iteration with loss 61.168077
#
# 1307 iteration with loss 61.132820
#
# 1308 iteration with loss 61.097625
#
# 1309 iteration with loss 61.062492
#
# 1310 iteration with loss 61.027420
#
# 1311 iteration with loss 60.992411
#
# 1312 iteration with loss 60.957463
#
# 1313 iteration with loss 60.922577
#
# 1314 iteration with loss 60.887752
#
# 1315 iteration with loss 60.852989
#
# 1316 iteration with loss 60.818287
#
# 1317 iteration with loss 60.783645
#
# 1318 iteration with loss 60.749065
#
# 1319 iteration with loss 60.714545
#
# 1320 iteration with loss 60.680086
#
# 1321 iteration with loss 60.645687
#
# 1322 iteration with loss 60.611349
#
# 1323 iteration with loss 60.577071
#
# 1324 iteration with loss 60.542853
#
# 1325 iteration with loss 60.508694
#
# 1326 iteration with loss 60.474596
#
# 1327 iteration with loss 60.440557
#
# 1328 iteration with loss 60.406578
#
# 1329 iteration with loss 60.372658
#
# 1330 iteration with loss 60.338797
#
# 1331 iteration with loss 60.304995
#
# 1332 iteration with loss 60.271253
#
# 1333 iteration with loss 60.237569
#
# 1334 iteration with loss 60.203944
#
# 1335 iteration with loss 60.170377
#
# 1336 iteration with loss 60.136869
#
# 1337 iteration with loss 60.103419
#
# 1338 iteration with loss 60.070027
#
# 1339 iteration with loss 60.036694
#
# 1340 iteration with loss 60.003418
#
# 1341 iteration with loss 59.970200
#
# ...
#
# 24507 iteration with loss 35.215587
#
# 24508 iteration with loss 35.215587
#
# 24509 iteration with loss 35.215587
#
# 24510 iteration with loss 35.215587
#
# 24511 iteration with loss 35.215587
#
# 24512 iteration with loss 35.215587
#
# 24513 iteration with loss 35.215587
#
# 24514 iteration with loss 35.215587
#
# 24515 iteration with loss 35.215587
#
# 24516 iteration with loss 35.215587
#
# 24517 iteration with loss 35.215587
#
# 24518 iteration with loss 35.215587
#
# 24519 iteration with loss 35.215587
#
# 24520 iteration with loss 35.215587
#
# 24521 iteration with loss 35.215587
#
# 24522 iteration with loss 35.215587
#
# 24523 iteration with loss 35.215587
#
# 24524 iteration with loss 35.215587
#
# 24525 iteration with loss 35.215587
#
# 24526 iteration with loss 35.215587
#
# 24527 iteration with loss 35.215587
#
# 24528 iteration with loss 35.215587
#
# 24529 iteration with loss 35.215587
#
# 24530 iteration with loss 35.215587
#
# 24531 iteration with loss 35.215587
#
# 24532 iteration with loss 35.215587
#
# 24533 iteration with loss 35.215587
#
# 24534 iteration with loss 35.215587
#
# 24535 iteration with loss 35.215587
#
# 24536 iteration with loss 35.215587
#
# 24537 iteration with loss 35.215587
#
# 24538 iteration with loss 35.215587
#
# 24539 iteration with loss 35.215587
#
# 24540 iteration with loss 35.215587
#
# 24541 iteration with loss 35.215587
#
# 24542 iteration with loss 35.215587
#
# 24543 iteration with loss 35.215587
#
# 24544 iteration with loss 35.215587
#
# 24545 iteration with loss 35.215587
#
# 24546 iteration with loss 35.215587
#
# 24547 iteration with loss 35.215587
#
# 24548 iteration with loss 35.215587
#
# 24549 iteration with loss 35.215587
#
# 24550 iteration with loss 35.215587
#
# 24551 iteration with loss 35.215587
#
# 24552 iteration with loss 35.215587
#
# 24553 iteration with loss 35.215587
#
# 24554 iteration with loss 35.215587
#
# 24555 iteration with loss 35.215587
#
# 24556 iteration with loss 35.215587
#
# 24557 iteration with loss 35.215587
#
# 24558 iteration with loss 35.215587
#
# 24559 iteration with loss 35.215587
#
# 24560 iteration with loss 35.215587
#
# 24561 iteration with loss 35.215587
#
# 24562 iteration with loss 35.215587
#
# 24563 iteration with loss 35.215587
#
# 24564 iteration with loss 35.215587
#
# 24565 iteration with loss 35.215586
#
# 24566 iteration with loss 35.215586
#
# 24567 iteration with loss 35.215586
#
# 24568 iteration with loss 35.215586
#
# 24569 iteration with loss 35.215586
#
# 24570 iteration with loss 35.215586
#
# 24571 iteration with loss 35.215586
#
# 24572 iteration with loss 35.215586
#
# 24573 iteration with loss 35.215586
#
# 24574 iteration with loss 35.215586
#
# 24575 iteration with loss 35.215586
#
# 24576 iteration with loss 35.215586
#
# 24577 iteration with loss 35.215586
#
# 24578 iteration with loss 35.215586
#
# 24579 iteration with loss 35.215586
#
# 24580 iteration with loss 35.215586
#
# 24581 iteration with loss 35.215586
#
# 24582 iteration with loss 35.215586
#
# 24583 iteration with loss 35.215586
#
# 24584 iteration with loss 35.215586
#
# 24585 iteration with loss 35.215586
#
# 24586 iteration with loss 35.215586
#
# 24587 iteration with loss 35.215586
#
# 24588 iteration with loss 35.215586
#
# 24589 iteration with loss 35.215586
#
# 24590 iteration with loss 35.215586
#
# 24591 iteration with loss 35.215586
#
# 24592 iteration with loss 35.215586
#
# 24593 iteration with loss 35.215586
#
# 24594 iteration with loss 35.215586
#
# 24595 iteration with loss 35.215586
#
# 24596 iteration with loss 35.215586
#
# 24597 iteration with loss 35.215586
#
# 24598 iteration with loss 35.215586
#
# 24599 iteration with loss 35.215586
#
# 24600 iteration with loss 35.215586
#
# 24601 iteration with loss 35.215586
#
# 24602 iteration with loss 35.215586
#
# 24603 iteration with loss 35.215586
#
# 24604 iteration with loss 35.215586
#
# 24605 iteration with loss 35.215586
#
# 24606 iteration with loss 35.215586
#
# 24607 iteration with loss 35.215586
#
# 24608 iteration with loss 35.215586
#
# 24609 iteration with loss 35.215586
#
# 24610 iteration with loss 35.215586
#
# 24611 iteration with loss 35.215586
#
# 24612 iteration with loss 35.215586
#
# 24613 iteration with loss 35.215586
#
# 24614 iteration with loss 35.215586
#
# 24615 iteration with loss 35.215586
#
# 24616 iteration with loss 35.215586
#
# 24617 iteration with loss 35.215586
#
# 24618 iteration with loss 35.215586
#
# 24619 iteration with loss 35.215586
#
# 24620 iteration with loss 35.215586
#
# 24621 iteration with loss 35.215586
#
# 24622 iteration with loss 35.215586
#
# 24623 iteration with loss 35.215586
#
# 24624 iteration with loss 35.215586
#
# 24625 iteration with loss 35.215586
#
# 24626 iteration with loss 35.215586
#
# 24627 iteration with loss 35.215586
#
# 24628 iteration with loss 35.215586
#
# 24629 iteration with loss 35.215586
#
# 24630 iteration with loss 35.215586
#
# 24631 iteration with loss 35.215586
#
# 24632 iteration with loss 35.215586
#
# 24633 iteration with loss 35.215586
#
# 24634 iteration with loss 35.215586
#
# 24635 iteration with loss 35.215586
#
# 24636 iteration with loss 35.215586
#
# 24637 iteration with loss 35.215586
#
# 24638 iteration with loss 35.215586
#
# 24639 iteration with loss 35.215586
#
# 24640 iteration with loss 35.215586
#
# 24641 iteration with loss 35.215586
#
# 24642 iteration with loss 35.215586
#
# 24643 iteration with loss 35.215586
#
# 24644 iteration with loss 35.215586
#
# 24645 iteration with loss 35.215586
#
# 24646 iteration with loss 35.215586
#
# 24647 iteration with loss 35.215586
#
# 24648 iteration with loss 35.215586
#
# 24649 iteration with loss 35.215586
#
# 24650 iteration with loss 35.215586
#
# 24651 iteration with loss 35.215586
#
# 24652 iteration with loss 35.215585
#
# 24653 iteration with loss 35.215585
#
# 24654 iteration with loss 35.215585
#
# 24655 iteration with loss 35.215585
#
# 24656 iteration with loss 35.215585
#
# 24657 iteration with loss 35.215585
#
# 24658 iteration with loss 35.215585
#
# 24659 iteration with loss 35.215585
#
# 24660 iteration with loss 35.215585
#
# 24661 iteration with loss 35.215585
#
# 24662 iteration with loss 35.215585
#
# 24663 iteration with loss 35.215585
#
# 24664 iteration with loss 35.215585
#
# 24665 iteration with loss 35.215585
#
# 24666 iteration with loss 35.215585
#
# 24667 iteration with loss 35.215585
#
# 24668 iteration with loss 35.215585
#
# 24669 iteration with loss 35.215585
#
# 24670 iteration with loss 35.215585
#
# 24671 iteration with loss 35.215585
#
# 24672 iteration with loss 35.215585
#
# 24673 iteration with loss 35.215585
#
# 24674 iteration with loss 35.215585
#
# 24675 iteration with loss 35.215585
#
# 24676 iteration with loss 35.215585
#
# 24677 iteration with loss 35.215585
#
# 24678 iteration with loss 35.215585
#
# 24679 iteration with loss 35.215585
#
# 24680 iteration with loss 35.215585
#
# 24681 iteration with loss 35.215585
# 24682 iteration with loss 35.215585
#
# 24683 iteration with loss 35.215585
#
# 24684 iteration with loss 35.215585
#
# 24685 iteration with loss 35.215585
#
# 24686 iteration with loss 35.215585
#
# 24687 iteration with loss 35.215585
#
# 24688 iteration with loss 35.215585
#
# 24689 iteration with loss 35.215585
#
# 24690 iteration with loss 35.215585
#
# 24691 iteration with loss 35.215585
#
# 24692 iteration with loss 35.215585
#
# 24693 iteration with loss 35.215585
#
# 24694 iteration with loss 35.215585
#
# 24695 iteration with loss 35.215585
#
# 24696 iteration with loss 35.215585
#
# 24697 iteration with loss 35.215585
#
# 24698 iteration with loss 35.215585
#
# 24699 iteration with loss 35.215585
#
# 24700 iteration with loss 35.215585
#
# 24701 iteration with loss 35.215585
#
# 24702 iteration with loss 35.215585
#
# 24703 iteration with loss 35.215585
#
# 24704 iteration with loss 35.215585
#
# 24705 iteration with loss 35.215585
#
# 24706 iteration with loss 35.215585
#
# 24707 iteration with loss 35.215585
#
# 24708 iteration with loss 35.215585
#
# 24709 iteration with loss 35.215585
#
# 24710 iteration with loss 35.215585
#
# 24711 iteration with loss 35.215585
#
# 24712 iteration with loss 35.215585
#
# 24713 iteration with loss 35.215585
#
# 24714 iteration with loss 35.215585
#
# 24715 iteration with loss 35.215585
#
# 24716 iteration with loss 35.215585
#
# 24717 iteration with loss 35.215585
#
# 24718 iteration with loss 35.215585
#
# 24719 iteration with loss 35.215585
#
# 24720 iteration with loss 35.215585
#
# 24721 iteration with loss 35.215585
#
# 24722 iteration with loss 35.215585
#
# 24723 iteration with loss 35.215585
#
# 24724 iteration with loss 35.215585
#
# 24725 iteration with loss 35.215585
#
# 24726 iteration with loss 35.215585
#
# 24727 iteration with loss 35.215585
#
# 24728 iteration with loss 35.215585
#
# 24729 iteration with loss 35.215585
#
# 24730 iteration with loss 35.215585
#
# 24731 iteration with loss 35.215585
#
# 24732 iteration with loss 35.215585
#
# 24733 iteration with loss 35.215585
#
# 24734 iteration with loss 35.215585
#
# 24735 iteration with loss 35.215585
#
# 24736 iteration with loss 35.215585
#
# 24737 iteration with loss 35.215585
#
# 24738 iteration with loss 35.215585
#
# 24739 iteration with loss 35.215585
#
# 24740 iteration with loss 35.215585
#
# 24741 iteration with loss 35.215585
#
# 24742 iteration with loss 35.215585
#
# 24743 iteration with loss 35.215584
#
# 24744 iteration with loss 35.215584
#
# 24745 iteration with loss 35.215584
#
# 24746 iteration with loss 35.215584
#
# 24747 iteration with loss 35.215584
#
# 24748 iteration with loss 35.215584
#
# 24749 iteration with loss 35.215584
#
# 24750 iteration with loss 35.215584
#
# 24751 iteration with loss 35.215584
#
# 24752 iteration with loss 35.215584
#
# 24753 iteration with loss 35.215584
#
# 24754 iteration with loss 35.215584
#
# 24755 iteration with loss 35.215584
#
# 24756 iteration with loss 35.215584
#
# 24757 iteration with loss 35.215584
#
# 24758 iteration with loss 35.215584
#
# 24759 iteration with loss 35.215584
#
# 24760 iteration with loss 35.215584
#
# 24761 iteration with loss 35.215584
#
# 24762 iteration with loss 35.215584
#
# 24763 iteration with loss 35.215584
#
# 24764 iteration with loss 35.215584
#
# 24765 iteration with loss 35.215584
#
# 24766 iteration with loss 35.215584
#
# 24767 iteration with loss 35.215584
#
# 24768 iteration with loss 35.215584
#
# 24769 iteration with loss 35.215584
#
# 24770 iteration with loss 35.215584
#
# 24771 iteration with loss 35.215584
#
# 24772 iteration with loss 35.215584
#
# 24773 iteration with loss 35.215584
#
# 24774 iteration with loss 35.215584
#
# 24775 iteration with loss 35.215584
#
# 24776 iteration with loss 35.215584
#
# 24777 iteration with loss 35.215584
#
# 24778 iteration with loss 35.215584
#
# 24779 iteration with loss 35.215584
#
# 24780 iteration with loss 35.215584
#
# 24781 iteration with loss 35.215584
#
# 24782 iteration with loss 35.215584
#
# 24783 iteration with loss 35.215584
#
# 24784 iteration with loss 35.215584
#
# 24785 iteration with loss 35.215584
#
# 24786 iteration with loss 35.215584
#
# 24787 iteration with loss 35.215584
#
# 24788 iteration with loss 35.215584
#
# 24789 iteration with loss 35.215584
#
# 24790 iteration with loss 35.215584
#
# 24791 iteration with loss 35.215584
#
# 24792 iteration with loss 35.215584
#
# 24793 iteration with loss 35.215584
#
# 24794 iteration with loss 35.215584
#
# 24795 iteration with loss 35.215584
#
# 24796 iteration with loss 35.215584
#
# 24797 iteration with loss 35.215584
#
# 24798 iteration with loss 35.215584
#
# 24799 iteration with loss 35.215584
#
# 24800 iteration with loss 35.215584
#
# 24801 iteration with loss 35.215584
#
# 24802 iteration with loss 35.215584
#
# 24803 iteration with loss 35.215584
#
# 24804 iteration with loss 35.215584
#
# 24805 iteration with loss 35.215584
#
# 24806 iteration with loss 35.215584
#
# 24807 iteration with loss 35.215584
#
# 24808 iteration with loss 35.215584
#
# 24809 iteration with loss 35.215584
#
# 24810 iteration with loss 35.215584
#
# 24811 iteration with loss 35.215584
#
# 24812 iteration with loss 35.215584
#
# 24813 iteration with loss 35.215584
#
# 24814 iteration with loss 35.215584
#
# 24815 iteration with loss 35.215584
#
# 24816 iteration with loss 35.215584
#
# 24817 iteration with loss 35.215584
#
# 24818 iteration with loss 35.215584
#
# 24819 iteration with loss 35.215584
#
# 24820 iteration with loss 35.215584
#
# 24821 iteration with loss 35.215584
#
# 24822 iteration with loss 35.215584
#
# 24823 iteration with loss 35.215584
#
# 24824 iteration with loss 35.215584
#
# 24825 iteration with loss 35.215584
#
# 24826 iteration with loss 35.215584
#
# 24827 iteration with loss 35.215584
#
# 24828 iteration with loss 35.215584
#
# 24829 iteration with loss 35.215584
#
# 24830 iteration with loss 35.215584
#
# 24831 iteration with loss 35.215584
#
# 24832 iteration with loss 35.215584
#
# 24833 iteration with loss 35.215584
#
# 24834 iteration with loss 35.215584
#
# 24835 iteration with loss 35.215584
#
# 24836 iteration with loss 35.215584
#
# 24837 iteration with loss 35.215583
#
# 24838 iteration with loss 35.215583
#
# 24839 iteration with loss 35.215583
#
# 24840 iteration with loss 35.215583
#
# 24841 iteration with loss 35.215583
#
# 24842 iteration with loss 35.215583
#
# 24843 iteration with loss 35.215583
#
# 24844 iteration with loss 35.215583
#
# 24845 iteration with loss 35.215583
#
# 24846 iteration with loss 35.215583
#
# 24847 iteration with loss 35.215583
#
# 24848 iteration with loss 35.215583
#
# 24849 iteration with loss 35.215583
#
# 24850 iteration with loss 35.215583
#
# 24851 iteration with loss 35.215583
#
# 24852 iteration with loss 35.215583
#
# 24853 iteration with loss 35.215583
#
# 24854 iteration with loss 35.215583
#
# 24855 iteration with loss 35.215583
#
# 24856 iteration with loss 35.215583
#
# 24857 iteration with loss 35.215583
#
# 24858 iteration with loss 35.215583
#
# 24859 iteration with loss 35.215583
#
# 24860 iteration with loss 35.215583
#
# 24861 iteration with loss 35.215583
#
# 24862 iteration with loss 35.215583
#
# 24863 iteration with loss 35.215583
#
# 24864 iteration with loss 35.215583
#
# 24865 iteration with loss 35.215583
#
# 24866 iteration with loss 35.215583
#
# 24867 iteration with loss 35.215583
#
# 24868 iteration with loss 35.215583
#
# 24869 iteration with loss 35.215583
#
# 24870 iteration with loss 35.215583
#
# 24871 iteration with loss 35.215583
#
# 24872 iteration with loss 35.215583
#
# 24873 iteration with loss 35.215583
#
# 24874 iteration with loss 35.215583
#
# 24875 iteration with loss 35.215583
#
# 24876 iteration with loss 35.215583
#
# 24877 iteration with loss 35.215583
#
# 24878 iteration with loss 35.215583
#
# 24879 iteration with loss 35.215583
#
# 24880 iteration with loss 35.215583
#
# 24881 iteration with loss 35.215583
#
# 24882 iteration with loss 35.215583
#
# 24883 iteration with loss 35.215583
#
# 24884 iteration with loss 35.215583
#
# 24885 iteration with loss 35.215583
#
# 24886 iteration with loss 35.215583
#
# 24887 iteration with loss 35.215583
#
# 24888 iteration with loss 35.215583
#
# 24889 iteration with loss 35.215583
#
# 24890 iteration with loss 35.215583
#
# 24891 iteration with loss 35.215583
#
# 24892 iteration with loss 35.215583
#
# 24893 iteration with loss 35.215583
#
# 24894 iteration with loss 35.215583
#
# 24895 iteration with loss 35.215583
#
# 24896 iteration with loss 35.215583
#
# 24897 iteration with loss 35.215583
#
# 24898 iteration with loss 35.215583
#
# 24899 iteration with loss 35.215583
#
# 24900 iteration with loss 35.215583
#
# 24901 iteration with loss 35.215583
#
# 24902 iteration with loss 35.215583
#
# 24903 iteration with loss 35.215583
#
# 24904 iteration with loss 35.215583
#
# 24905 iteration with loss 35.215583
#
# 24906 iteration with loss 35.215583
#
# 24907 iteration with loss 35.215583
#
# 24908 iteration with loss 35.215583
#
# 24909 iteration with loss 35.215583
#
# 24910 iteration with loss 35.215583
#
# 24911 iteration with loss 35.215583
#
# 24912 iteration with loss 35.215583
#
# 24913 iteration with loss 35.215583
#
# 24914 iteration with loss 35.215583
#
# 24915 iteration with loss 35.215583
#
# 24916 iteration with loss 35.215583
#
# 24917 iteration with loss 35.215583
#
# 24918 iteration with loss 35.215583
#
# 24919 iteration with loss 35.215583
#
# 24920 iteration with loss 35.215583
#
# 24921 iteration with loss 35.215583
#
# 24922 iteration with loss 35.215583
#
# 24923 iteration with loss 35.215583
#
# 24924 iteration with loss 35.215583
#
# 24925 iteration with loss 35.215583
#
# 24926 iteration with loss 35.215583
#
# 24927 iteration with loss 35.215583
#
# 24928 iteration with loss 35.215583
#
# 24929 iteration with loss 35.215583
#
# 24930 iteration with loss 35.215583
#
# 24931 iteration with loss 35.215583
#
# 24932 iteration with loss 35.215583
#
# 24933 iteration with loss 35.215583
#
# 24934 iteration with loss 35.215582
#
# 24935 iteration with loss 35.215582
#
# 24936 iteration with loss 35.215582
#
# 24937 iteration with loss 35.215582
#
# 24938 iteration with loss 35.215582

# %%
test_raw = []
with open("test.csv", 'r') as test_f:
    for line in test_f:
        line = line.replace('NR', '0.0')
        data = line.strip('\n').split(',')
        test_raw.append(data)

# %%
output_csv = []
print('id,value')
for i in range(240):
    idx = test_raw[i*18][0]

    test_x = []
    for f in range(18):
        if f in feature_set:
            test_x += test_raw[i*18+f][2+(9-prev_hrs):11]

    test_x = list(map(float, test_x))
    test_x = np.array(test_x)

    y = np.dot(w,test_x)+b

    print('%s,%f' % (idx, y))
    output_csv.append([idx,y])
# Out:
# id,value
# id_0,25.362352
# id_1,64.260327
# id_2,20.421328
# id_3,29.047546
# id_4,9.974105
# id_5,36.251988
# id_6,39.233640
# id_7,16.174863
# id_8,51.120900
# id_9,33.382664
# id_10,38.989656
# id_11,55.263309
# id_12,35.124267
# id_13,39.653408
# id_14,26.933700
# id_15,12.480590
# id_16,51.594068
# id_17,22.924055
# id_18,17.377067
# id_19,18.475052
# id_20,15.721177
# id_21,30.452932
# id_22,38.103020
# id_23,9.586280
# id_24,58.452289
# id_25,44.045837
# id_26,26.672272
# id_27,8.586159
# id_28,30.782196
# id_29,35.788588
# id_30,17.232567
# id_31,11.265173
# id_32,16.440516
# id_33,6.785747
# id_34,16.949011
# id_35,40.119542
# id_36,19.966448
# id_37,27.125447
# id_38,10.234033
# id_39,62.159046
# id_40,47.439325
# id_41,18.694129
# id_42,52.282677
# id_43,18.217000
# id_44,44.734187
# id_45,50.403756
# id_46,59.860090
# id_47,41.706951
# id_48,50.867294
# id_49,39.980736
# id_50,28.695814
# id_51,23.508593
# id_52,40.139124
# id_53,24.093483
# id_54,38.075339
# id_55,41.173976
# id_56,24.341041
# id_57,22.772189
# id_58,36.735192
# id_59,32.532114
# id_60,15.335933
# id_61,24.761026
# id_62,32.198092
# id_63,54.452066
# id_64,48.428533
# id_65,25.910545
# id_66,38.879500
# id_67,52.663813
# id_68,25.842254
# id_69,36.591478
# id_70,62.981280
# id_71,55.521536
# id_72,43.600127
# id_73,12.956446
# id_74,10.718034
# id_75,36.989701
# id_76,61.665508
# id_77,2.017455
# id_78,43.055265
# id_79,41.007036
# id_80,9.110734
# id_81,22.755592
# id_82,5.404896
# id_83,30.916533
# id_84,9.698629
# id_85,7.614412
# id_86,16.975001
# id_87,11.811351
# id_88,15.155174
# id_89,26.399735
# id_90,35.354031
# id_91,11.957460
# id_92,14.218295
# id_93,7.535962
# id_94,37.983086
# id_95,16.893096
# id_96,15.834511
# id_97,8.085897
# id_98,12.072655
# id_99,6.540972
# id_100,10.959188
# id_101,18.318790
# id_102,11.687123
# id_103,8.730725
# id_104,13.419061
# id_105,37.153153
# id_106,25.561315
# id_107,7.029213
# id_108,16.025881
# id_109,15.440076
# id_110,13.007014
# id_111,17.459410
# id_112,15.324339
# id_113,26.572858
# id_114,21.157181
# id_115,17.811708
# id_116,7.708554
# id_117,46.223608
# id_118,26.707983
# id_119,1.853261
# id_120,1.731020
# id_121,9.773124
# id_122,14.917790
# id_123,13.856137
# id_124,8.023502
# id_125,26.199961
# id_126,21.129894
# id_127,11.879532
# id_128,20.764191
# id_129,17.967003
# id_130,1.583918
# id_131,35.097483
# id_132,15.070524
# id_133,23.539786
# id_134,25.932984
# id_135,22.180354
# id_136,9.929157
# id_137,21.514702
# id_138,79.412904
# id_139,64.131383
# id_140,28.574604
# id_141,20.232540
# id_142,24.394034
# id_143,7.797838
# id_144,10.487060
# id_145,10.978054
# id_146,19.120966
# id_147,9.020938
# id_148,11.644217
# id_149,15.639698
# id_150,48.432298
# id_151,20.997132
# id_152,24.304784
# id_153,14.717470
# id_154,15.558233
# id_155,26.257732
# id_156,21.867290
# id_157,35.951983
# id_158,3.664814
# id_159,20.211680
# id_160,45.585484
# id_161,18.589623
# id_162,61.856084
# id_163,18.774915
# id_164,35.426014
# id_165,24.078583
# id_166,22.921008
# id_167,-0.419874
# id_168,67.358560
# id_169,18.788164
# id_170,17.404935
# id_171,72.320124
# id_172,20.744417
# id_173,1.878603
# id_174,22.943747
# id_175,2.241838
# id_176,6.829220
# id_177,16.273339
# id_178,19.660805
# id_179,21.470133
# id_180,44.139265
# id_181,29.839757
# id_182,27.561683
# id_183,11.804357
# id_184,7.310194
# id_185,40.919007
# id_186,36.242751
# id_187,36.164329
# id_188,15.577893
# id_189,22.235835
# id_190,14.706443
# id_191,16.471957
# id_192,32.438416
# id_193,75.356330
# id_194,29.872303
# id_195,12.765005
# id_196,63.977708
# id_197,16.234802
# id_198,18.772260
# id_199,22.336869
# id_200,128.687676
# id_201,24.762867
# id_202,57.577000
# id_203,6.746041
# id_204,60.630203
# id_205,36.285186
# id_206,14.874075
# id_207,12.957362
# id_208,65.134844
# id_209,15.124790
# id_210,30.822561
# id_211,70.514391
# id_212,21.081815
# id_213,114.579295
# id_214,41.404015
# id_215,78.779072
# id_216,95.364395
# id_217,72.989818
# id_218,30.684784
# id_219,18.613969
# id_220,31.154682
# id_221,55.455683
# id_222,27.672412
# id_223,39.207307
# id_224,43.801250
# id_225,7.337607
# id_226,3.545077
# id_227,71.911543
# id_228,29.569954
# id_229,1.473695
# id_230,40.340736
# id_231,13.438547
# id_232,20.081890
# id_233,8.616444
# id_234,12.402294
# id_235,22.881845
# id_236,12.328946
# id_237,-1.264227
# id_238,21.838640
# id_239,2.143832

# %%
fileHeader = ['id','value']
csvFile = open('answer.csv', "w+")
writer = csv.writer(csvFile)
writer.writerow(fileHeader)
for j in range(len(output_csv)):
    writer.writerow(output_csv[j])
csvFile.close()
